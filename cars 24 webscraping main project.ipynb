# %%
# Import all the necessary libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import requests
from bs4 import BeautifulSoup # here b and s should be capital
import re

#from bs4 import BeautifulSoup as bs

# %%
# here you have to copy the url
URL = "https://www.cars24.com/buy-used-car/?sort=P&storeCityId=3686&pinId=500001&utm_source=google&utm_medium=cpc&utm_keyword=used%20car%20buying%20sites&utm_matchtype=p&utm_device=c&adgroup_id=140653988601&campaign_id=17333455664&gclid=CjwKCAjw5P2aBhAlEiwAAdY7dDxC7D3wof4d4KCxAcf0EpsV5hUk18poaGAR60GwnUGjoeYd7XKyMxoCWToQAvD_BwE&gclid=CjwKCAjw5P2aBhAlEiwAAdY7dDxC7D3wof4d4KCxAcf0EpsV5hUk18poaGAR60GwnUGjoeYd7XKyMxoCWToQAvD_BwE"

# %%
# here requesting for url
page = requests.get(URL)

# %%
# getting the page status code 
page.status_code
# Out:
# 200

# %%
# get the HTML content from the page
pagecontent = page.text
pagecontent
# Out:
# '<!DOCTYPE html>\n\n<html lang="en">\n\n<head>\n    <link rel="preconnect" href="//www.googleoptimize.com" />\n    <link rel="preconnect" href="//www.googletagmanager.com" />\n    <link rel="preconnect" href="//www.google-analytics.com" />\n    <link rel="preconnect" href="//connect.facebook.net" />\n    <link rel="preconnect" href="//cdn.jsdelivr.net" />\n    <link rel="preconnect" href="//widgets.getsitecontrol.com" />\n    <link rel="preconnect" href="//s.yimg.com" />\n    <link rel="preconnect" href="//www.googleadservices.com" />\n    <link rel="preconnect" href="//d2r1yp2w7bby2u.cloudfront.net" /><meta charset="UTF-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" />\n    <meta property="fb:app_id" content="697234207046254" /><!--scripts from helmet--><link data-react-helmet="true" href="https://www.cars24.com/buy-used-car/" rel="canonical"/><link data-react-helmet="true" rel="preload" href="https://fastly-product
# ...

# %%
# beautifulsoup is a python library used to extract the html content from the web 
soup = BeautifulSoup(pagecontent)

# %%
#getting all the data 
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="//www.googleoptimize.com" rel="preconnect"/>
# <link href="//www.googletagmanager.com" rel="preconnect"/>
# <link href="//www.google-analytics.com" rel="preconnect"/>
# <link href="//connect.facebook.net" rel="preconnect"/>
# <link href="//cdn.jsdelivr.net" rel="preconnect"/>
# <link href="//widgets.getsitecontrol.com" rel="preconnect"/>
# <link href="//s.yimg.com" rel="preconnect"/>
# <link href="//www.googleadservices.com" rel="preconnect"/>
# <link href="//d2r1yp2w7bby2u.cloudfront.net" rel="preconnect"/><meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
# ...

# %%
# knowing the type of the soup
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
# here you have to take the url from one of their results "mainly the title" so their you get all the necessary info
name=soup.find_all("h2", class_="_3FpCg")

# %%
# here we are appending the elements into the names DF and coping them in the text
names=[]
for i in name:
    names.append(i.text)

# %%
# showing the result of names in the general scenario
names
# Out:
# ['2016 Hyundai Grand i10',
#  '2019 Maruti Alto 800',
#  '2022 Maruti Swift',
#  '2021 Nissan MAGNITE',
#  '2012 Hyundai i10',
#  '2011 Hyundai i20',
#  '2014 Maruti Alto 800',
#  '2019 Volkswagen Polo',
#  '2012 Hyundai i10',
#  '2012 Maruti Swift Dzire',
#  '2017 Maruti Celerio',
#  '2012 Hyundai i10',
#  '2016 Volkswagen Polo',
#  '2021 Maruti Swift',
#  '2012 Hyundai i10',
#  '2013 Maruti Swift Dzire',
#  '2012 Hyundai i10',
#  '2018 Maruti Celerio',
#  '2016 Hyundai Creta',
#  '2016 Renault Kwid']

# %%
# know the len of the names
len(names)
# Out:
# 20

# %%
# taking the price factor
price = soup.find_all("div",class_="_19zc5")

# %%
# taking for loop and extracting the data
prices=[]
for i in price:
    prices.append(i.text)

# %%
# showing the result of pries in the general scenario
prices
# Out:
# ['₹8,790/month₹4,49,599',
#  '₹5,668/month₹2,89,899',
#  '₹17,160/month₹9,13,799',
#  '₹19,196/month₹10,22,199',
#  '₹7,527/month₹3,84,999',
#  '₹7,181/month₹3,67,299',
#  '₹5,486/month₹2,80,599',
#  '₹11,001/month₹5,62,699',
#  '₹7,413/month₹3,79,199',
#  '₹9,595/month₹4,90,799',
#  '₹8,364/month₹4,27,799',
#  '₹6,815/month₹3,48,599',
#  '₹10,061/month₹5,14,599',
#  '₹13,842/month₹7,07,999',
#  '₹7,638/month₹3,90,699',
#  '₹8,158/month₹4,17,299',
#  '₹7,544/month₹3,85,899',
#  '₹9,052/month₹4,62,999',
#  '₹20,790/month₹11,07,099',
#  '₹6,508/month₹3,32,899']

# %%
# know the len of the prices
len(prices)
# Out:
# 20

# %%
# here we take the var_1 as a variable because the data internally have some column data
var_1=soup.find_all("ul", class_="bVR0c")

# %%
# taking for loop and extracting the data
var_11=[]
for i in var_1:
    var_11.append(i.text)

# %%
var_11 #having values of "how many kilometers have travelled","is it 1st owner or 2nd or 3rd","type of engine:"
# Out:
# ['11,662 km2nd OwnerPetrolAP-05',
#  '79,158 km1st OwnerPetrolTS-17',
#  '25,341 km1st OwnerPetrolTS-05',
#  '8,857 km1st OwnerPetrolTS-07',
#  '72,233 km3rd OwnerPetrolAP-09',
#  '44,456 km3rd OwnerPetrolAP-28',
#  '33,431 km1st OwnerPetrolAP-10',
#  '59,938 km1st OwnerPetrolTS-13',
#  '68,072 km2nd OwnerPetrolAP-29',
#  '57,048 km1st OwnerPetrolAP-28',
#  '78,499 km2nd OwnerPetrolTS-08',
#  '41,562 km2nd OwnerPetrolAP-23',
#  '79,315 km2nd OwnerPetrolTS-15',
#  '45,332 km1st OwnerPetrolTS-08',
#  '54,545 km2nd OwnerPetrolAP-28',
#  '91,029 km2nd OwnerPetrolAP-28',
#  '72,561 km1st OwnerPetrolAP-28',
#  '89,184 km2nd OwnerPetrolTS-13',
#  '60,076 km1st OwnerDieselTS-07',
#  '29,404 km2nd OwnerPetrolTS-09']

# %%
len(var_11) #finding the length
# Out:
# 20

# %%
# here we take the model variable because it consists of "Manual or Automated","type of vehicle"
model =soup.find_all("p",class_="cvakB")

# %%
# taking the for loop and appending them
models=[]
for i in model:
    models.append(i.text)

# %%
# displaying the models data
models
# Out:
# ['SPORTZ 1.2 KAPPA VTVT Manual',
#  'LXI Manual',
#  'ZXI+ DUAL TONE ',
#  'XV PRM. TURBO . MT PETROL ',
#  'SPORTZ 1.2 AT KAPPA2 Automatic',
#  'MAGNA O 1.2 Manual',
#  'LXI Manual',
#  'Trendline 1.0 L Petrol Manual',
#  'SPORTZ 1.2 AT KAPPA2 Automatic',
#  'ZXI 1.2 BS IV Manual',
#  'ZXI Manual',
#  'SPORTZ 1.2 KAPPA2 Manual',
#  'COMFORTLINE 1.2L PETROL Manual',
#  'VXI Manual',
#  'SPORTZ 1.2 AT KAPPA2 Automatic',
#  'VXI Manual',
#  'SPORTZ 1.2 AT KAPPA2 Automatic',
#  'VXI (O) AMT Automatic',
#  '1.6 SX (O) CRDI Manual',
#  '1.0 RXT Manual']

# %%
len(models) # finding the length
# Out:
# 20

# %%
import requests
from bs4 import BeautifulSoup

# %%
#here we are defining the included columns in the dataframe and creating lists on them
names=[]
prices=[]
var_11=[]
models=[]
#list_ids means here we are adding cityids and their pincodes
list_ids=["CityId=2&pinId=110001","CityId=134&pinId=201301","CityId=5&pinId=122001","CityId=2378&pinId=400001","CityId=2423&pinId=411001","CityId=4709&pinId=560001","CityId=3686&pinId=500001","CityId=5732&pinId=600001","CityId=777&pinId=700001","CityId=1692&pinId=380001","CityId=135&pinId=202001","CityId=1771&pinId=387315","CityId=1822&pinId=392001","CityId=2987&pinId=462001","CityId=769&pinId=134101","CityId=6105&pinId=641001","CityId=6&pinId=121001","CityId=132&pinId=201001","CityId=2920&pinId=450001","CityId=2130&pinId=302001"]
for i in list_ids:
    url="https://www.cars24.com/buy-used-car?sort=P&store"+i #it is the main full URL for every city
    page = requests.get(url)
    soup=BeautifulSoup(page.content)
    name=soup.find_all("h2", class_="_3FpCg")
    for i in name:
        if i is None:
            names.append(np.Nan)
        else:
            names.append(i.text)
    price=soup.find_all("div",class_="_19zc5")
    for i in price:
        if i is None:
            pricess.append(np.Nan)
        else:
            prices.append(i.text)
    var_1 = soup.find_all("ul", class_="bVR0c")
    for i in var_1:
        if i is None:
            var_11.append(np.Nan)
        else:
            var_11.append(i.text)
    model =soup.find_all("p",class_="cvakB")
    for i in model:
        if i is None:
            models.append(np.Nan)
        else:
            models.append(i.text)

# %%
len(names)
# Out:
# 400

# %%
len(prices)
# Out:
# 400

# %%
len(var_11)
# Out:
# 400

# %%
len(models)
# Out:
# 400

# %%
import pandas as pd

# %%
data=pd.DataFrame({'name':names, 'price': prices, "var_1":var_11, "model":models})

# %%
data
# Out:
#                        name                    price  \
# 0         2019 Maruti Swift   ₹10,326/month₹5,28,199
# 1         2020 Maruti Swift   ₹11,583/month₹5,92,499
# 2    2018 Hyundai Grand i10   ₹10,686/month₹5,46,599
# 3         2021 Maruti Swift   ₹10,868/month₹5,55,899
# 4         2020 Maruti Swift   ₹10,893/month₹5,57,199
# ..                      ...                      ...
# 395      2021 Maruti Baleno   ₹13,929/month₹7,12,499
# 396   2018 Mahindra Scorpio  ₹29,765/month₹15,84,999
# 397       2018 Maruti Swift   ₹11,675/month₹5,97,199
# 398       2017 Maruti Swift   ₹10,989/month₹5,62,099
# 399      2012 Toyota Innova   ₹10,111/month₹5,17,199
#
#                                var_1                         model
# 0      12,046 km2nd OwnerPetrolDL-4C                    LXI Manual
# 1       6,758 km1st OwnerPetrolDL-1C                    LXI Manual
# 2       6,875 km2nd OwnerPetrolUP-16  SPORTZ 1.2 KAPPA VTVT Manual
# ...

# %%
data.to_csv("cars24.csv")

# %% [markdown]
# ## Data Cleaning

# %%
cars=pd.read_csv("cars24.csv")

# %%
cars
# Out:
#      Unnamed: 0                    name                    price  \
# 0             0       2019 Maruti Swift   ₹10,326/month₹5,28,199
# 1             1       2020 Maruti Swift   ₹11,583/month₹5,92,499
# 2             2  2018 Hyundai Grand i10   ₹10,686/month₹5,46,599
# 3             3       2021 Maruti Swift   ₹10,868/month₹5,55,899
# 4             4       2020 Maruti Swift   ₹10,893/month₹5,57,199
# ..          ...                     ...                      ...
# 395         395      2021 Maruti Baleno   ₹13,929/month₹7,12,499
# 396         396   2018 Mahindra Scorpio  ₹29,765/month₹15,84,999
# 397         397       2018 Maruti Swift   ₹11,675/month₹5,97,199
# 398         398       2017 Maruti Swift   ₹10,989/month₹5,62,099
# 399         399      2012 Toyota Innova   ₹10,111/month₹5,17,199
#
#                                var_1                         model
# 0      12,046 km2nd OwnerPetrolDL-4C                    LXI Manual
# ...

# %%
#n=data.name[399].split()
names=[]
for i in cars.name:
    n=i.split()
    names.append(" ".join(n[1:]))

# %%
cars['names']=names

# %%
cars
# Out:
#      Unnamed: 0                    name                    price  \
# 0             0       2019 Maruti Swift   ₹10,326/month₹5,28,199
# 1             1       2020 Maruti Swift   ₹11,583/month₹5,92,499
# 2             2  2018 Hyundai Grand i10   ₹10,686/month₹5,46,599
# 3             3       2021 Maruti Swift   ₹10,868/month₹5,55,899
# 4             4       2020 Maruti Swift   ₹10,893/month₹5,57,199
# ..          ...                     ...                      ...
# 395         395      2021 Maruti Baleno   ₹13,929/month₹7,12,499
# 396         396   2018 Mahindra Scorpio  ₹29,765/month₹15,84,999
# 397         397       2018 Maruti Swift   ₹11,675/month₹5,97,199
# 398         398       2017 Maruti Swift   ₹10,989/month₹5,62,099
# 399         399      2012 Toyota Innova   ₹10,111/month₹5,17,199
#
#                                var_1                         model  \
# 0      12,046 km2nd OwnerPetrolDL-4C                    LXI Manual
# ...

# %%
d=cars.name.str.split(" ")

year=[]
for i in d:
    y=i[0]
    year.append(y)

# %%
cars['year']=year

# %%
cars.drop('name',axis=1)
# Out:
#      Unnamed: 0                    price                            var_1  \
# 0             0   ₹10,326/month₹5,28,199    12,046 km2nd OwnerPetrolDL-4C
# 1             1   ₹11,583/month₹5,92,499     6,758 km1st OwnerPetrolDL-1C
# 2             2   ₹10,686/month₹5,46,599     6,875 km2nd OwnerPetrolUP-16
# 3             3   ₹10,868/month₹5,55,899    13,174 km1st OwnerPetrolDL-5C
# 4             4   ₹10,893/month₹5,57,199    16,633 km2nd OwnerPetrolHR-51
# ..          ...                      ...                              ...
# 395         395   ₹13,929/month₹7,12,499    37,838 km1st OwnerPetrolRJ-45
# 396         396  ₹29,765/month₹15,84,999    55,798 km2nd OwnerDieselRJ-25
# 397         397   ₹11,675/month₹5,97,199    83,770 km1st OwnerPetrolRJ-02
# 398         398   ₹10,989/month₹5,62,099    14,361 km1st OwnerPetrolRJ-14
# 399         399   ₹10,111/month₹5,17,199  2,02,313 km2nd OwnerDieselRJ-23
#
#                             model              names  year
# ...

# %%
cars['price'][0].replace("₹","").replace(",","").replace("/month"," ").split()[1]
# Out:
# '528199'

# %%
cars['emi']= cars['price'].apply(lambda x: x.replace("₹","").replace(",","").replace("/month"," ").split()[0])

# %%
cars['total price']= cars['price'].apply(lambda x: x.replace("₹","").replace(",","").replace("/month"," ").split()[1])

# %%
cars
# Out:
#      Unnamed: 0                    name                    price  \
# 0             0       2019 Maruti Swift   ₹10,326/month₹5,28,199
# 1             1       2020 Maruti Swift   ₹11,583/month₹5,92,499
# 2             2  2018 Hyundai Grand i10   ₹10,686/month₹5,46,599
# 3             3       2021 Maruti Swift   ₹10,868/month₹5,55,899
# 4             4       2020 Maruti Swift   ₹10,893/month₹5,57,199
# ..          ...                     ...                      ...
# 395         395      2021 Maruti Baleno   ₹13,929/month₹7,12,499
# 396         396   2018 Mahindra Scorpio  ₹29,765/month₹15,84,999
# 397         397       2018 Maruti Swift   ₹11,675/month₹5,97,199
# 398         398       2017 Maruti Swift   ₹10,989/month₹5,62,099
# 399         399      2012 Toyota Innova   ₹10,111/month₹5,17,199
#
#                                var_1                         model  \
# 0      12,046 km2nd OwnerPetrolDL-4C                    LXI Manual
# ...

# %%
cars.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
cars
# Out:
#                        name                    price  \
# 0         2019 Maruti Swift   ₹10,326/month₹5,28,199
# 1         2020 Maruti Swift   ₹11,583/month₹5,92,499
# 2    2018 Hyundai Grand i10   ₹10,686/month₹5,46,599
# 3         2021 Maruti Swift   ₹10,868/month₹5,55,899
# 4         2020 Maruti Swift   ₹10,893/month₹5,57,199
# ..                      ...                      ...
# 395      2021 Maruti Baleno   ₹13,929/month₹7,12,499
# 396   2018 Mahindra Scorpio  ₹29,765/month₹15,84,999
# 397       2018 Maruti Swift   ₹11,675/month₹5,97,199
# 398       2017 Maruti Swift   ₹10,989/month₹5,62,099
# 399      2012 Toyota Innova   ₹10,111/month₹5,17,199
#
#                                var_1                         model  \
# 0      12,046 km2nd OwnerPetrolDL-4C                    LXI Manual
# 1       6,758 km1st OwnerPetrolDL-1C                    LXI Manual
# 2       6,875 km2nd OwnerPetrolUP-16  SPORTZ 1.2 KAPPA VTVT Manual
# ...

# %%
cars.drop(['name','price'],axis=1,inplace=True)
cars
# Out:
#                                var_1                         model  \
# 0      12,046 km2nd OwnerPetrolDL-4C                    LXI Manual
# 1       6,758 km1st OwnerPetrolDL-1C                    LXI Manual
# 2       6,875 km2nd OwnerPetrolUP-16  SPORTZ 1.2 KAPPA VTVT Manual
# 3      13,174 km1st OwnerPetrolDL-5C                    LXI Manual
# 4      16,633 km2nd OwnerPetrolHR-51                    LXI Manual
# ..                               ...                           ...
# 395    37,838 km1st OwnerPetrolRJ-45           ZETA 1.2 K12 Manual
# 396    55,798 km2nd OwnerDieselRJ-25                    S11 Manual
# 397    83,770 km1st OwnerPetrolRJ-02                    VXI Manual
# 398    14,361 km1st OwnerPetrolRJ-14                VXI OPT Manual
# 399  2,02,313 km2nd OwnerDieselRJ-23     2.5 GX 8 STR BS IV Manual
#
#                  names  year    emi total price
# 0         Maruti Swift  2019  10326      528199
# 1         Maruti Swift  2020  11583      592499
# ...

# %%
#cars['var_1'][0].replace("km","").replace("Owner","")
#here you should be carefull because k is in capital and owner "o "is in capital
cars['var_1']=cars['var_1'].apply(lambda x:x.replace("km","").replace("Owner",""))

# %%
cars
# Out:
#                         var_1                         model  \
# 0      12,046 2nd PetrolDL-4C                    LXI Manual
# 1       6,758 1st PetrolDL-1C                    LXI Manual
# 2       6,875 2nd PetrolUP-16  SPORTZ 1.2 KAPPA VTVT Manual
# 3      13,174 1st PetrolDL-5C                    LXI Manual
# 4      16,633 2nd PetrolHR-51                    LXI Manual
# ..                        ...                           ...
# 395    37,838 1st PetrolRJ-45           ZETA 1.2 K12 Manual
# 396    55,798 2nd DieselRJ-25                    S11 Manual
# 397    83,770 1st PetrolRJ-02                    VXI Manual
# 398    14,361 1st PetrolRJ-14                VXI OPT Manual
# 399  2,02,313 2nd DieselRJ-23     2.5 GX 8 STR BS IV Manual
#
#                  names  year    emi total price
# 0         Maruti Swift  2019  10326      528199
# 1         Maruti Swift  2020  11583      592499
# 2    Hyundai Grand i10  2018  10686      546599
# 3         Maruti Swift  2021  10868      555899
# ...

# %%
cars[['kilometers_driven', 'owner', 'type_of_engine']]=cars['var_1'].str.split(' ',2,expand=True)

# %%
cars.drop(['var_1'],axis=1,inplace=True)
cars
# Out:
#                             model              names  year    emi total price  \
# 0                      LXI Manual       Maruti Swift  2019  10326      528199
# 1                      LXI Manual       Maruti Swift  2020  11583      592499
# 2    SPORTZ 1.2 KAPPA VTVT Manual  Hyundai Grand i10  2018  10686      546599
# 3                      LXI Manual       Maruti Swift  2021  10868      555899
# 4                      LXI Manual       Maruti Swift  2020  10893      557199
# ..                            ...                ...   ...    ...         ...
# 395           ZETA 1.2 K12 Manual      Maruti Baleno  2021  13929      712499
# 396                    S11 Manual   Mahindra Scorpio  2018  29765     1584999
# 397                    VXI Manual       Maruti Swift  2018  11675      597199
# 398                VXI OPT Manual       Maruti Swift  2017  10989      562099
# 399     2.5 GX 8 STR BS IV Manual      Toyota Innova  2012  10111      517199
#
# ...

# %%
cars['kilometers_driven']=cars['kilometers_driven'].apply(lambda x:x.replace(",",""))
cars
# Out:
#                             model              names  year    emi total price  \
# 0                      LXI Manual       Maruti Swift  2019  10326      528199
# 1                      LXI Manual       Maruti Swift  2020  11583      592499
# 2    SPORTZ 1.2 KAPPA VTVT Manual  Hyundai Grand i10  2018  10686      546599
# 3                      LXI Manual       Maruti Swift  2021  10868      555899
# 4                      LXI Manual       Maruti Swift  2020  10893      557199
# ..                            ...                ...   ...    ...         ...
# 395           ZETA 1.2 K12 Manual      Maruti Baleno  2021  13929      712499
# 396                    S11 Manual   Mahindra Scorpio  2018  29765     1584999
# 397                    VXI Manual       Maruti Swift  2018  11675      597199
# 398                VXI OPT Manual       Maruti Swift  2017  10989      562099
# 399     2.5 GX 8 STR BS IV Manual      Toyota Innova  2012  10111      517199
#
# ...

# %%
cars['kilometers_driven']=cars['kilometers_driven'].astype(str).astype(int)

# %%
cars['emi']=cars['emi'].astype(str).astype(int)

# %%
cars['total price']=cars['total price'].astype(str).astype(int)

# %%
#cars_pd.rename(columns={'names':'car_name'},inplace=True)

# %%
cars.info()
cars
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   model              400 non-null    object
#  1   names              400 non-null    object
#  2   year               400 non-null    object
#  3   emi                400 non-null    int32
#  4   total price        400 non-null    int32
#  5   kilometers_driven  400 non-null    int32
#  6   owner              400 non-null    object
#  7   type_of_engine     400 non-null    object
# dtypes: int32(3), object(5)
# memory usage: 20.4+ KB
#                             model              names  year    emi  \
# 0                      LXI Manual       Maruti Swift  2019  10326
# 1                      LXI Manual       Maruti Swift  2020  11583
# 2    SPORTZ 1.2 KAPPA VTVT Manual  Hyundai Grand i10  2018  10686
# 3                      LXI Manual       Maruti Swift  2021  10868
# ...

# %%
cars['model']
# Out:
# 0                        LXI Manual
# 1                        LXI Manual
# 2      SPORTZ 1.2 KAPPA VTVT Manual
# 3                        LXI Manual
# 4                        LXI Manual
#                    ...
# 395             ZETA 1.2 K12 Manual
# 396                      S11 Manual
# 397                      VXI Manual
# 398                  VXI OPT Manual
# 399       2.5 GX 8 STR BS IV Manual
# Name: model, Length: 400, dtype: object

# %%
cars[['model_name', 'transmission_type']]=cars['model'].str.split(' ',1,expand=True)

cars['transmission_type'].str.split(" ")[:]
# Out:
# 0                          [Manual]
# 1                          [Manual]
# 2        [1.2, KAPPA, VTVT, Manual]
# 3                          [Manual]
# 4                          [Manual]
#                    ...
# 395              [1.2, K12, Manual]
# 396                        [Manual]
# 397                        [Manual]
# 398                   [OPT, Manual]
# 399    [GX, 8, STR, BS, IV, Manual]
# Name: transmission_type, Length: 400, dtype: object

# %%
#cars[['model_name']]=cars['model'].str.extract(r'^[:\b]')

# %%
cars.drop(['model'],axis=1,inplace=True)
cars
# Out:
#                  names  year    emi  total price  kilometers_driven owner  \
# 0         Maruti Swift  2019  10326       528199              12046   2nd
# 1         Maruti Swift  2020  11583       592499               6758   1st
# 2    Hyundai Grand i10  2018  10686       546599               6875   2nd
# 3         Maruti Swift  2021  10868       555899              13174   1st
# 4         Maruti Swift  2020  10893       557199              16633   2nd
# ..                 ...   ...    ...          ...                ...   ...
# 395      Maruti Baleno  2021  13929       712499              37838   1st
# 396   Mahindra Scorpio  2018  29765      1584999              55798   2nd
# 397       Maruti Swift  2018  11675       597199              83770   1st
# 398       Maruti Swift  2017  10989       562099              14361   1st
# 399      Toyota Innova  2012  10111       517199             202313   2nd
#
#     type_of_engine model_name      transmission_type
# ...

# %%
#cars[['type_of_enginess','registration_num']]=cars['type_of_engine'].str.split('-',1,expand=True)

# %%
#cars

# %%
cars['type_of_engine'].unique()
# Out:
# array(['PetrolDL-4C', 'PetrolDL-1C', 'PetrolUP-16', 'PetrolDL-5C',
#        'PetrolHR-51', 'PetrolDL-3C', 'PetrolHR-26', 'PetrolDL-12',
#        'Petrol + CNGDL-5C', 'PetrolDL-9C', 'PetrolUP-70', 'PetrolHR-11',
#        'PetrolUP-14', 'Petrol + CNGHR-51', 'PetrolDL-6C', 'PetrolDL-7C',
#        'PetrolDL-10', 'DieselUP-14', 'PetrolDL-11', 'PetrolDL-8C',
#        'DieselUP-70', 'DieselDL-1C', 'DieselDL-3C', 'PetrolMH-02',
#        'PetrolMH-01', 'PetrolMH-05', 'PetrolMH-46', 'Petrol + CNGMH-46',
#        'PetrolMH-31', 'PetrolMH-43', 'PetrolMH-03', 'Petrol + CNGMH-47',
#        'Petrol + CNGMH-05', 'PetrolMH-04', 'PetrolMH-14', 'PetrolMH-12',
#        'DieselMH-12', 'PetrolMH-49', 'PetrolMH-47', 'DieselMH-02',
#        'PetrolKA-03', 'PetrolKA-41', 'DieselKA-05', 'PetrolKA-05',
#        'PetrolKA-51', 'PetrolKA-04', 'PetrolKA-02', 'PetrolKA-01',
#        'PetrolKA-53', 'PetrolAP-05', 'PetrolTS-17', 'PetrolTS-05',
#        'PetrolTS-07', 'PetrolAP-09', 'PetrolAP-28', 'PetrolAP-10',
# ...

# %%
cars_eng=[re.findall('[A-Z]{2}\-[0-9]{2}',str(i))for i in cars['type_of_engine']]

# %%
import re
cars_eng=[re.findall('([A-Z]{2}\-[0-9]{0,2}[A-Z]{0,2})',str(i))[0] if re.search('([A-Z]{2}\-[0-9]{0,2}[A-Z]{0,2})',str(i)) else np.nan for i in cars['type_of_engine'] ]

# %%
cars_eng
# Out:
# ['DL-4C',
#  'DL-1C',
#  'UP-16',
#  'DL-5C',
#  'HR-51',
#  'UP-16',
#  'DL-3C',
#  'UP-16',
#  'HR-26',
#  'DL-12',
#  'HR-26',
#  'DL-5C',
#  'DL-12',
#  'DL-9C',
#  'DL-3C',
#  'UP-70',
#  'DL-9C',
#  'HR-11',
#  'UP-14',
#  'HR-26',
#  'UP-14',
#  'DL-4C',
#  'DL-3C',
#  'DL-9C',
#  'DL-3C',
#  'UP-14',
#  'UP-16',
#  'HR-51',
#  'HR-26',
#  'DL-3C',
#  'HR-26',
#  'DL-6C',
#  'DL-7C',
#  'DL-10',
#  'DL-12',
#  'UP-14',
#  'DL-3C',
#  'DL-11',
#  'HR-26',
#  'DL-8C',
#  'UP-70',
#  'DL-3C',
#  'DL-7C',
#  'HR-26',
#  'DL-9C',
#  'DL-1C',
#  'UP-16',
#  'DL-3C',
#  'UP-14',
#  'DL-1C',
#  'DL-3C',
#  'HR-11',
#  'DL-6C',
#  'DL-8C',
#  'DL-3C',
#  'DL-8C',
#  'DL-12',
#  'HR-26',
#  'DL-4C',
#  'UP-16',
#  'MH-02',
#  'MH-01',
#  'MH-05',
#  'MH-02',
#  'MH-02',
#  'MH-46',
#  'MH-02',
#  'MH-05',
#  'MH-46',
#  'MH-31',
#  'MH-43',
#  'MH-02',
#  'MH-05',
#  'MH-03',
#  'MH-05',
#  'MH-47',
#  'MH-02',
#  'MH-46',
#  'MH-05',
#  'MH-04',
#  'MH-01',
#  'MH-01',
#  'MH-05',
# ...

# %%
cars['reg_state']=cars_eng

# %%
cars.head()
# Out:
#                names  year    emi  total price  kilometers_driven owner  \
# 0       Maruti Swift  2019  10326       528199              12046   2nd
# 1       Maruti Swift  2020  11583       592499               6758   1st
# 2  Hyundai Grand i10  2018  10686       546599               6875   2nd
# 3       Maruti Swift  2021  10868       555899              13174   1st
# 4       Maruti Swift  2020  10893       557199              16633   2nd
#
#   type_of_engine model_name      transmission_type reg_state
# 0    PetrolDL-4C        LXI                 Manual     DL-4C
# 1    PetrolDL-1C        LXI                 Manual     DL-1C
# 2    PetrolUP-16     SPORTZ  1.2 KAPPA VTVT Manual     UP-16
# 3    PetrolDL-5C        LXI                 Manual     DL-5C
# 4    PetrolHR-51        LXI                 Manual     HR-51

# %%
import re
fuel=[re.findall('([petrolPETROLDIESELdiesel]{6})',str(i))[0] if re.search('([petrolPETROLDIESELdiesel]{6})',str(i)) else np.nan for i in cars['type_of_engine'] ]

# %%
fuel
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
# ...

# %%
cars['Engine_type']=fuel
cars.head()
# Out:
#                names  year    emi  total price  kilometers_driven owner  \
# 0       Maruti Swift  2019  10326       528199              12046   2nd
# 1       Maruti Swift  2020  11583       592499               6758   1st
# 2  Hyundai Grand i10  2018  10686       546599               6875   2nd
# 3       Maruti Swift  2021  10868       555899              13174   1st
# 4       Maruti Swift  2020  10893       557199              16633   2nd
#
#   type_of_engine model_name      transmission_type reg_state Engine_type
# 0    PetrolDL-4C        LXI                 Manual     DL-4C      Petrol
# 1    PetrolDL-1C        LXI                 Manual     DL-1C      Petrol
# 2    PetrolUP-16     SPORTZ  1.2 KAPPA VTVT Manual     UP-16      Petrol
# 3    PetrolDL-5C        LXI                 Manual     DL-5C      Petrol
# 4    PetrolHR-51        LXI                 Manual     HR-51      Petrol

# %%
cars.drop(['type_of_engine'],axis=1,inplace=True)
cars
# Out:
#                  names  year    emi  total price  kilometers_driven owner  \
# 0         Maruti Swift  2019  10326       528199              12046   2nd
# 1         Maruti Swift  2020  11583       592499               6758   1st
# 2    Hyundai Grand i10  2018  10686       546599               6875   2nd
# 3         Maruti Swift  2021  10868       555899              13174   1st
# 4         Maruti Swift  2020  10893       557199              16633   2nd
# ..                 ...   ...    ...          ...                ...   ...
# 395      Maruti Baleno  2021  13929       712499              37838   1st
# 396   Mahindra Scorpio  2018  29765      1584999              55798   2nd
# 397       Maruti Swift  2018  11675       597199              83770   1st
# 398       Maruti Swift  2017  10989       562099              14361   1st
# 399      Toyota Innova  2012  10111       517199             202313   2nd
#
#     model_name      transmission_type reg_state Engine_type
# ...

# %%
cars['transmission_type'] = cars['transmission_type'].str.extract(r'^.*?(A/T|Automatic|Auto|CVT|Manual|M/T)')

# %%
cars['transmission_type']
# Out:
# 0      Manual
# 1      Manual
# 2      Manual
# 3      Manual
# 4      Manual
#         ...
# 395    Manual
# 396    Manual
# 397    Manual
# 398    Manual
# 399    Manual
# Name: transmission_type, Length: 400, dtype: object

# %%
cars.head()
# Out:
#                names  year    emi  total price  kilometers_driven owner  \
# 0       Maruti Swift  2019  10326       528199              12046   2nd
# 1       Maruti Swift  2020  11583       592499               6758   1st
# 2  Hyundai Grand i10  2018  10686       546599               6875   2nd
# 3       Maruti Swift  2021  10868       555899              13174   1st
# 4       Maruti Swift  2020  10893       557199              16633   2nd
#
#   model_name transmission_type reg_state Engine_type
# 0        LXI            Manual     DL-4C      Petrol
# 1        LXI            Manual     DL-1C      Petrol
# 2     SPORTZ            Manual     UP-16      Petrol
# 3        LXI            Manual     DL-5C      Petrol
# 4        LXI            Manual     HR-51      Petrol

# %%
#cars.drop(['model_name_n','transmission_type_t'],axis=1,inplace=True)
cars
# Out:
#                  names  year    emi  total price  kilometers_driven owner  \
# 0         Maruti Swift  2019  10326       528199              12046   2nd
# 1         Maruti Swift  2020  11583       592499               6758   1st
# 2    Hyundai Grand i10  2018  10686       546599               6875   2nd
# 3         Maruti Swift  2021  10868       555899              13174   1st
# 4         Maruti Swift  2020  10893       557199              16633   2nd
# ..                 ...   ...    ...          ...                ...   ...
# 395      Maruti Baleno  2021  13929       712499              37838   1st
# 396   Mahindra Scorpio  2018  29765      1584999              55798   2nd
# 397       Maruti Swift  2018  11675       597199              83770   1st
# 398       Maruti Swift  2017  10989       562099              14361   1st
# 399      Toyota Innova  2012  10111       517199             202313   2nd
#
#     model_name transmission_type reg_state Engine_type
# ...

# %%
cars['transmission_type'].unique()
# Out:
# array(['Manual', 'Automatic', nan, 'A/T', 'CVT'], dtype=object)

# %%
cars.columns
# Out:
# Index(['names', 'year', 'emi', 'total price', 'kilometers_driven', 'owner',
#        'model_name', 'transmission_type', 'reg_state', 'Engine_type'],
#       dtype='object')

# %%
#cars[['model_name_n', 'transmission_type_t']]=cars['transmission_type'].str.split(' ',1,expand=True)
#cars

# %%
cars = cars[['year','names','model_name','owner','kilometers_driven','transmission_type','reg_state','Engine_type','emi','total price']]
cars
# Out:
#      year              names model_name owner  kilometers_driven  \
# 0    2019       Maruti Swift        LXI   2nd              12046
# 1    2020       Maruti Swift        LXI   1st               6758
# 2    2018  Hyundai Grand i10     SPORTZ   2nd               6875
# 3    2021       Maruti Swift        LXI   1st              13174
# 4    2020       Maruti Swift        LXI   2nd              16633
# ..    ...                ...        ...   ...                ...
# 395  2021      Maruti Baleno       ZETA   1st              37838
# 396  2018   Mahindra Scorpio        S11   2nd              55798
# 397  2018       Maruti Swift        VXI   1st              83770
# 398  2017       Maruti Swift        VXI   1st              14361
# 399  2012      Toyota Innova        2.5   2nd             202313
#
#     transmission_type reg_state Engine_type    emi  total price
# 0              Manual     DL-4C      Petrol  10326       528199
# ...

# %%
cars.isnull().sum()
# Out:
# year                  0
# names                 0
# model_name            0
# owner                 0
# kilometers_driven     0
# transmission_type    25
# reg_state             0
# Engine_type           0
# emi                   0
# total price           0
# dtype: int64

# %%
cars['transmission_type'].fillna(0, inplace=True)
cars.isnull().sum()
# Out:
# C:\Users\shanmukha varma\AppData\Local\Temp\ipykernel_16892\3236659964.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars['transmission_type'].fillna(0, inplace=True)
# year                 0
# names                0
# model_name           0
# owner                0
# kilometers_driven    0
# transmission_type    0
# reg_state            0
# Engine_type          0
# emi                  0
# total price          0
# dtype: int64

# %%
cars['transmission_type'].mode()
# Out:
# 0    Manual
# Name: transmission_type, dtype: object

# %%
cars['transmission_type'].replace(0,'Manual')
cars['transmission_type'].unique()
# Out:
# array(['Manual', 'Automatic', 'A/T', 'CVT'], dtype=object)

# %%
cars['year']=cars['year'].astype(int)

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   year               400 non-null    int32
#  1   names              400 non-null    object
#  2   model_name         400 non-null    object
#  3   owner              400 non-null    object
#  4   kilometers_driven  400 non-null    int32
#  5   transmission_type  400 non-null    object
#  6   reg_state          400 non-null    object
#  7   Engine_type        400 non-null    object
#  8   emi                400 non-null    int32
#  9   total price        400 non-null    int32
# dtypes: int32(4), object(6)
# memory usage: 25.1+ KB
